# %%
import pandas as pd

# Load the UK stations data
df_stations = pd.read_csv('/Users/trishapunamiya/Downloads/stations.csv')

# Filter for Scotland only
scotland_stations = df_stations[df_stations['constituentCountry'] == 'scotland'].copy()

print(f"Found {len(scotland_stations)} stations in Scotland")

# Save as JSON for your map
scotland_stations.to_json('scotland_train_stations.json', orient='records', indent=2)

print("✓ Scotland stations saved")
print("\nSample stations:")
print(scotland_stations[['stationName', 'lat', 'long']].head())
# Out:
# Found 363 stations in Scotland
# ✓ Scotland stations saved
#
# Sample stations:
#       stationName        lat      long
# 4        Aberdeen  57.143127 -2.097464
# 5        Aberdour  56.054646 -3.300575
# 12       Achanalt  57.609921 -4.914243
# 13     Achnasheen  57.579205 -5.072421
# 14  Achnashellach  57.482697 -5.333001
